# %% [markdown]
# # Westworld cleanup
#
# Fixing the raw data coming from the Fandom wiki
#
#
# ## TODO
# * [x] clean html
# * [x] clean wiki markup
# * [x] gender uppercase
# * [x] remove unwanted columns
# * [x] drop categories and old movie characters
# * [ ] standardize categoricals: species, status, seasons, ethnicity, hair, eye

# %%
import pandas as pd
import numpy as np
import re

pd.set_option('display.max_columns', None)

# %%
chars_raw = pd.read_csv('data/characters.csv', encoding='utf-8')
chars_raw.head()
# Out:
#      id           name                  url                        links  \
# 0  7655          Akane          /wiki/Akane                          NaN
# 1  7681       Akecheta       /wiki/Akecheta          ['Kohana', 'Maeve']
# 2  3182         Angela         /wiki/Angela                    ['Wyatt']
# 3  7615  Antoine Costa  /wiki/Antoine_Costa                          NaN
# 4  2165      Armistice      /wiki/Armistice  ['Hector Escaton', 'Wyatt']
#
#    is_host  is_human                                    image  \
# 0     True     False                         {{PAGENAME}}.jpg
# 1     True     False                  <gallery>\nAkecheta.png
# 2     True     False                       Angela Reunion.jpg
# 3    False      True                        Antoine Costa.png
# 4     True     False  <gallery>\n  Armistice Akane No Mai.jpg
#
#                                                  aka  \
# 0                                           あかね, アカネ
# 1  Ghost <small>(by the [[Homestead Girl]])</smal...
# 2                           "Angela the cult member"
# 3                                                NaN
# 4                                                NaN
#
#                                               status   species  gender  \
# 0                                             Active      Host  Female
# 1  Decommissioned <small>(conscious mind in the [...      Host    Male
# 2                                     Decommissioned  [[Host]]  Female
# 3                                           Deceased       NaN    Male
# 4                                     Decommissioned  [[Host]]  Female
#
#                      actor         seasons                        firstseen  \
# 0        [[Rinko Kikuchi]]  [[Season Two]]               "[[Akane No Mai]]"
# 1       [[Zahn McClarnon]]    [[Season Two                    "[[Reunion]]"
# 2        [[Talulah Riley]]    [[Season One                   "[[Chestnut]]"
# 3          [[Fares Fares]]    [[Season Two  "[[Journey_Into_Night_(episode)
# 4  [[Ingrid Bolsø Berdal]]    [[Season One               "[[The Original]]"
#
#               lastseen           ethnicity    hair    eye  \
# 0    "[[Phase Space]]"            Japanese   Black  Brown
# 1  "[[The Passenger]]"     Native American   Black  Brown
# 2   "[[Les Ecorches]]"   British Caucasian  Blonde  Hazel
# 3     "[[The_Passenger                 NaN   Black  Brown
# 4                  NaN  Caucasian American  Blonde    NaN
#
#                                    death  \
# 0                                    NaN
# 1  "[[Kiksuya]]"<br/>"[[The Passenger]]"
# 2                                    NaN
# 3                                    NaN
# 4                                    NaN
#
#                                           occupation  \
# 0                                                NaN
# 1  Leader of the [[Ghost Nation]]<br/>Tribesman <...
# 2             Townswoman, Guest Greeter, Cult Member
# 3                                         Technician
# 4                                                NaN
#
#                                deathdate  \
# 0                                    NaN
# 1  June 2052 <small>(last death)</small>
# 2                                    NaN
# 3                                    NaN
# 4                                    NaN
#
#                                           deathcause  \
# 0                                                NaN
# 1  Repeatedly stabbed in the gut by a guest <smal...
# 2           self-destruction by detonating a grenade
# 3  Shot repeatedly by [[Dolores Abernathy]] <smal...
# 4                                                NaN
#
#                               family  age                            images  \
# 0                                NaN  NaN                               NaN
# 1  [[Kohana]] <small>(lover)</small>  NaN                               NaN
# 2                                NaN  30s                               NaN
# 3                                NaN  NaN  [[:Category:Images of {{PAGENAME
# 4                                NaN  30s   [[:Category:Images of Armistice
#
#   imagecaption appearedin height weight title park creationdate birth origin  \
# 0          NaN        NaN    NaN    NaN   NaN  NaN          NaN   NaN    NaN
# 1          NaN        NaN    NaN    NaN   NaN  NaN          NaN   NaN    NaN
# 2          NaN        NaN    NaN    NaN   NaN  NaN          NaN   NaN    NaN
# 3          NaN        NaN    NaN    NaN   NaN  NaN          NaN   NaN    NaN
# 4          NaN        NaN    NaN    NaN   NaN  NaN          NaN   NaN    NaN
#
#   headquarter type language leadership founder eyes
# 0         NaN  NaN      NaN        NaN     NaN  NaN
# 1         NaN  NaN      NaN        NaN     NaN  NaN
# 2         NaN  NaN      NaN        NaN     NaN  NaN
# 3         NaN  NaN      NaN        NaN     NaN  NaN
# 4         NaN  NaN      NaN        NaN     NaN  NaN

# %% [markdown]
# ---

# %%
chars = chars_raw.copy()

# Drop unused columns
"""
image, images, imagecaption: just filenames of images in the wiki
appearedin: infrequently used episode count or list of episode names
"""
drop_cols = ['image',  'images', 'imagecaption', 'appearedin']
chars = chars.drop(columns=drop_cols)
# Drop mostly empty columns (less than 15 non-null values)
chars = chars.dropna(axis=1, how='any', thresh=15)


def remove_html(s):
    """Converts some html tags to unicode, then discards the rest."""
    s = re.sub(r'<br/>', '\n', s)
    s = re.sub(html_reftag, '', s)
    s =  re.sub(html_remove_r, '', s)
    return s


def remove_markdown(s):
    """Remove double brackets and bullets for wiki markdown"""
    s = re.sub(r'\[{2}|\]{2}', '', s) 
    s = re.sub(r'\*', '', s)
    return s

# Compile regex for cleaning
html_remove_r = re.compile('<.*?>')
html_reftag = re.compile(r'<ref.*</ref>')

# Clean all string columns
for col in chars.select_dtypes(include='object'):
    chars[col] = (chars[col]
                  .map(remove_html, na_action='ignore')
                  .map(remove_markdown, na_action='ignore')
                 )
    # Replace every TBA with null
    chars[col] = chars[col].replace(to_replace='TBA', value=None)

# Gender to uppercase
chars['gender'] = chars['gender'].str.upper()

# Drop movie characters
chars = chars.drop(index=chars[chars.name.str.contains(r'\(19[0-9]{2}\)')].index)

# Drop categories
chars = chars.drop(index=chars[chars.url.str.contains('Category')].index)



def fix_species(df):
    """Map certain abnormal values of species."""
    species_map = {
        'Human & Host': 'Both',
        'Unknown': None,
        'Host/Simulated': 'Simulation',
        'Human/Simulation': 'Simulation',
    }
    df['species'] = df['species'].replace(species_map)

fix_species(chars)

# %%
chars.head()
# Out:
#      id           name                  url                        links  \
# 0  7655          Akane          /wiki/Akane                          NaN
# 1  7681       Akecheta       /wiki/Akecheta          ['Kohana', 'Maeve']
# 2  3182         Angela         /wiki/Angela                    ['Wyatt']
# 3  7615  Antoine Costa  /wiki/Antoine_Costa                          NaN
# 4  2165      Armistice      /wiki/Armistice  ['Hector Escaton', 'Wyatt']
#
#    is_host  is_human                                             aka  \
# 0     True     False                                        あかね, アカネ
# 1     True     False  Ghost (by the Homestead Girl)\nAke (by Kohana)
# 2     True     False                        "Angela the cult member"
# 3    False      True                                             NaN
# 4     True     False                                             NaN
#
#                                               status species  gender  \
# 0                                             Active    Host  FEMALE
# 1  Decommissioned (conscious mind in the Valley B...    Host    MALE
# 2                                     Decommissioned    Host  FEMALE
# 3                                           Deceased     NaN    MALE
# 4                                     Decommissioned    Host  FEMALE
#
#                  actor     seasons                      firstseen  \
# 0        Rinko Kikuchi  Season Two                 "Akane No Mai"
# 1       Zahn McClarnon  Season Two                      "Reunion"
# 2        Talulah Riley  Season One                     "Chestnut"
# 3          Fares Fares  Season Two  "Journey_Into_Night_(episode)
# 4  Ingrid Bolsø Berdal  Season One                 "The Original"
#
#           lastseen           ethnicity    hair    eye  \
# 0    "Phase Space"            Japanese   Black  Brown
# 1  "The Passenger"     Native American   Black  Brown
# 2   "Les Ecorches"   British Caucasian  Blonde  Hazel
# 3   "The_Passenger                 NaN   Black  Brown
# 4              NaN  Caucasian American  Blonde    NaN
#
#                         death  \
# 0                         NaN
# 1  "Kiksuya"\n"The Passenger"
# 2                         NaN
# 3                         NaN
# 4                         NaN
#
#                                           occupation  \
# 0                                                NaN
# 1  Leader of the Ghost Nation\nTribesman (formerl...
# 2             Townswoman, Guest Greeter, Cult Member
# 3                                         Technician
# 4                                                NaN
#
#                                           deathcause          family  age
# 0                                                NaN             NaN  NaN
# 1  Repeatedly stabbed in the gut by a guest (repa...  Kohana (lover)  NaN
# 2           self-destruction by detonating a grenade             NaN  30s
# 3  Shot repeatedly by Dolores Abernathy (as Charl...             NaN  NaN
# 4                                                NaN             NaN  30s

# %%
(chars.notna().sum()).sort_values()
# Out:
# death          15
# aka            21
# family         28
# deathcause     30
# links          33
# eye            34
# hair           59
# age            67
# occupation     67
# ethnicity      76
# lastseen       77
# species       105
# seasons       112
# status        115
# gender        115
# firstseen     115
# actor         116
# is_host       160
# url           160
# name          160
# is_human      160
# id            160
# dtype: int64

# %%
chars.seasons.value_counts()
# Out:
# Season One                62
# Season Three              24
# Season Two                23
# Season One, Season Two     3
# Name: seasons, dtype: int64

# %%
chars.loc[chars.fillna('').seasons.str.contains(',')]
# Out:
#        id                 name                        url links  is_host  \
# 11   3552  Barkeep (Las Mudas)  /wiki/Barkeep_(Las_Mudas)   NaN     True
# 68   7816      Gold Miner Host      /wiki/Gold_Miner_Host   NaN     True
# 128  3378      Revolutionaries      /wiki/Revolutionaries   NaN     True
#
#      is_human  aka          status species gender             actor  \
# 11      False  NaN  Decommissioned    Host   MALE      Price Carson
# 68      False  NaN          Active    Host   MALE  Micah Fitzgerald
# 128     False  NaN             NaN    Host    NaN               NaN
#
#                     seasons      firstseen                       lastseen  \
# 11   Season One, Season Two     "Chestnut"     "The Riddle of the Sphinx"
# 68   Season One, Season Two  "Trace Decay"  "Journey Into Night (episode)
# 128  Season One, Season Two  "Contrapasso"                      "Reunion"
#
#      ethnicity   hair   eye death occupation deathcause family  age
# 11         NaN    NaN   NaN   NaN    Barkeep        NaN    NaN  50s
# 68   Caucasian  Brown  Blue   NaN        NaN        NaN    NaN  40s
# 128        NaN    NaN   NaN   NaN        NaN        NaN    NaN  NaN

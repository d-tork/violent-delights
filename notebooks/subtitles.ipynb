# %%
import chardet
import pandas as pd
import re
from time import strptime

# %%
fpath = '../subtitles/Westworld - 2x01 - Journey Into Night.WEB.DEFLATE.en.srt'
with open(fpath, 'rb') as rawdata:
    result = chardet.detect(rawdata.read(100000))
print(result)
# Out:
# {'encoding': 'ISO-8859-1', 'confidence': 0.73, 'language': ''}

# %%
subtitle_dict = {
    'subtitle_index': [],
    'start': [],
    'end': [],
    'text': []
}

fpath = '../subtitles/Westworld - 2x01 - Journey Into Night.WEB.DEFLATE.en.srt'
with open(fpath, 'r', encoding='ISO-8859-1') as f:
    text_accumulator = []  # gathers multi-line subtitles
    for line in f:
        index_match = re.match(r'([0-9]+)\n', line)
        newline_match = re.fullmatch(r'\n', line)
        
        if index_match:
            # line is subtitle index
            index_int = int(index_match.group(1))
            subtitle_dict['subtitle_index'].append(index_int)
        elif re.search(r'-->', line):
            try:
                start, end = re.findall(r'([0-9]{2}:[0-9]{2}:[0-9]{1,2},[0-9]{2,3})', line)
            except ValueError:
                print(line)
            #subtitle_dict['start'].append(strptime(start, '%H:%M:%S,%f'))
            #subtitle_dict['end'].append(strptime(end, '%H:%M:%S,%f'))
            subtitle_dict['start'].append(start)
            subtitle_dict['end'].append(end)
        elif newline_match:
            # blank line between subtitles
            full_subtitle = ' '.join(text_accumulator)
            subtitle_dict['text'].append(full_subtitle)
            text_accumulator = []  # reset accumulator
        else:
            # text of the dialogue
            text_accumulator.append(line.strip())
    # Save the text contents of the last loop
    full_subtitle = ' '.join(text_accumulator)
    subtitle_dict['text'].append(full_subtitle)
            
for k, v in subtitle_dict.items():
    print(k, len(v))
# Out:
# subtitle_index 701
# start 701
# end 701
# text 701

# %%
all_lines[6].strip()
# Out:
# 'Welcome to Westworld.'

# %%
df = pd.DataFrame.from_dict(subtitle_dict)
df.head()
# Out:
#    subtitle_index         start           end  \
# 0               1  00:00:00,018  00:00:01,251
# 1               2  00:00:01,254  00:00:02,802
# 2               3  00:00:02,805  00:00:04,262
# 3               4  00:00:05,262  00:00:07,303
# 4               5  00:00:07,304  00:00:09,590
#
#                                                 text
# 0                                                  _
# 1                              Welcome to Westworld.
# 2                            Which would you prefer?
# 3                           This place is the answer
# 4  to that question that you've been asking yours...

# %%
for col in ['start', 'end']:
    df[col] = pd.to_datetime(df[col], format='%H:%M:%S,%f').dt.time

# %%
# Drop font color rows
df = df.drop(index=df.loc[df.text.str.contains('<font')].index)

# %%
df
# Out:
#      subtitle_index            start              end  \
# 0                 1  00:00:00.018000  00:00:01.251000
# 1                 2  00:00:01.254000  00:00:02.802000
# 2                 3  00:00:02.805000  00:00:04.262000
# 3                 4  00:00:05.262000  00:00:07.303000
# 4                 5  00:00:07.304000  00:00:09.590000
# ..              ...              ...              ...
# 694             695  01:11:33.979000  01:11:36.354000
# 695             696  01:11:38.081000  01:11:40.089000
# 696             697  01:11:58.730000  01:12:01.831000
# 697             698  01:12:01.834000  01:12:03.831000
# 698             699  01:12:07.062000  01:12:08.937000
#
#                                                   text
# 0                                                    _
# 1                                Welcome to Westworld.
# 2                              Which would you prefer?
# 3                             This place is the answer
# 4    to that question that you've been asking yours...
# ..                                                 ...
# 694                          which means I need yours.
# 695                     Can you tell me what happened?
# 696                                               I...
# 697                                     I killed them.
# 698                                       All of them.
#
# [698 rows x 4 columns]

# %% [markdown]
# ---
# ## Post- automated processing

# %%
df_subs = pd.read_csv('../data/subtitle_data.csv')
df_subs.head()
# Out:
#    subtitle_index            start              end  \
# 0               1  00:01:52.076000  00:01:53.876000
# 1               2  00:02:02.117000  00:02:03.787000
# 2               3  00:02:03.887000  00:02:05.417000
# 3               4  00:02:05.527000  00:02:08.088000
# 4               5  00:02:08.198000  00:02:09.898000
#
#                                               text  season_num  episode_num  \
# 0                    <i>Bring her back online.</i>           1            1
# 1                          <i>Can you hear me?</i>           1            1
# 2                                      <i>Yes.</i>           1            1
# 3  <i>I'm sorry. I'm not feeling quite myself.</i>           1            1
# 4                  <i>You can lose the accent.</i>           1            1
#
#    episode_name                                           filename  offscreen
# 0  The Original  Westworld - 1x01 - The Original.HDTV.FLEET.en.srt       True
# 1  The Original  Westworld - 1x01 - The Original.HDTV.FLEET.en.srt       True
# 2  The Original  Westworld - 1x01 - The Original.HDTV.FLEET.en.srt       True
# 3  The Original  Westworld - 1x01 - The Original.HDTV.FLEET.en.srt       True
# 4  The Original  Westworld - 1x01 - The Original.HDTV.FLEET.en.srt       True

# %%
# Split text on hyphens (multi-line, multi-person subtitle)
df_subs['textsplit'] = df_subs['text'].str.split(pat='- ')
# Remove empty strings from textsplit lists
df_subs['textsplit'] = df_subs['textsplit'].apply(lambda l: [x for x in l if len(x) > 0])
df_subs.head()
# Out:
#    subtitle_index            start              end  \
# 0               1  00:01:52.076000  00:01:53.876000
# 1               2  00:02:02.117000  00:02:03.787000
# 2               3  00:02:03.887000  00:02:05.417000
# 3               4  00:02:05.527000  00:02:08.088000
# 4               5  00:02:08.198000  00:02:09.898000
#
#                                               text  season_num  episode_num  \
# 0                    <i>Bring her back online.</i>           1            1
# 1                          <i>Can you hear me?</i>           1            1
# 2                                      <i>Yes.</i>           1            1
# 3  <i>I'm sorry. I'm not feeling quite myself.</i>           1            1
# 4                  <i>You can lose the accent.</i>           1            1
#
#    episode_name                                           filename  offscreen  \
# 0  The Original  Westworld - 1x01 - The Original.HDTV.FLEET.en.srt       True
# 1  The Original  Westworld - 1x01 - The Original.HDTV.FLEET.en.srt       True
# 2  The Original  Westworld - 1x01 - The Original.HDTV.FLEET.en.srt       True
# 3  The Original  Westworld - 1x01 - The Original.HDTV.FLEET.en.srt       True
# 4  The Original  Westworld - 1x01 - The Original.HDTV.FLEET.en.srt       True
#
#                                            textsplit
# 0                    [<i>Bring her back online.</i>]
# 1                          [<i>Can you hear me?</i>]
# 2                                      [<i>Yes.</i>]
# 3  [<i>I'm sorry. I'm not feeling quite myself.</i>]
# 4                  [<i>You can lose the accent.</i>]

# %%
# Explode the dataframe based on textsplit contents
df_subs = df_subs.explode('textsplit')

# %%
# Extract any text preceding a colon
speaker_pat = r'(.+):.*'
df_subs['speaker'] = df_subs.textsplit.str.extract(speaker_pat)
df_subs['speaker'] = df_subs.speaker.str.upper()
# Drop any "speakers" that are longer than 3 words
df_subs['speaker_word_count'] = df_subs['speaker'].fillna('').str.split().map(len)
df_subs['speaker_attributable'] = (df_subs.speaker_word_count > 0) & (df_subs.speaker_word_count <= 3)

# %%
df_subs.loc[df_subs.speaker_attributable, ['textsplit', 'offscreen', 'speaker']]
# Out:
#                                             textsplit  offscreen  \
# 373                               man #2: Hyah! Hyah!      False
# 2246     Man, distorted: Aw, can you fucking kill it?      False
# 2935           Old Bill: You got any stories, friend?      False
# 2969                                    Man: Find me.      False
# 2970                            Dolores: Show me how.      False
# ...                                               ...        ...
# 4311                 Lutz: <i>It's your codebase,</i>       True
# 4320                          Sylvester: <i>Lots.</i>       True
# 4356                              Elsie:<i> Hey.</i>        True
# 4381  Dr. Ford: I don't want you to worry about Jock.      False
# 8513                                Except one thing:      False
#
#                speaker
# 373             MAN #2
# 2246    MAN, DISTORTED
# 2935          OLD BILL
# 2969               MAN
# 2970           DOLORES
# ...                ...
# 4311              LUTZ
# 4320         SYLVESTER
# 4356             ELSIE
# 4381          DR. FORD
# 8513  EXCEPT ONE THING
#
# [73 rows x 3 columns]

# %%
df_subs.loc[df_subs.speaker_attributable, 'speaker'].str.upper().value_counts()
# Out:
# LOGAN               9
# MAN                 9
# DR. FORD            6
# WOMAN               5
# LUTZ                4
# ELSIE               3
# SYLVESTER           3
# EL LAZO             2
# TEDDY               2
# WAITER              2
# FEMALE VOICE        2
# WILLIAM             2
# MAN IN BLACK        2
# LAWRENCE            2
# BARTENDER           2
# THERESA             1
# STUBBS              1
# CAPTAIN             1
# BERNARD             1
# WOMAN'S VOICE       1
# MAN #2              1
# OLD BILL            1
# WOMAN #2            1
# EXCEPT ONE THING    1
# SLIM                1
# MAN, DISTORTED      1
# MAEVE               1
# MALE VOICE          1
# BOY                 1
# LAST CONTACT        1
# ROBERT              1
# SOLDIER             1
# DOLORES             1
# Name: speaker, dtype: int64

# %%
df_subs.loc[~df_subs.speaker_attributable, 'speaker'].str.upper().value_counts()
# Out:
# SYMPTOMS OF CRITICAL CORRUPTION                  1
# BUT ONE THING IS CONSTANT                        1
# I PRESENT OUR GUESTS' NEXT OBSESSION             1
# LET ME TELL YOU SOMETHING                        1
# SHE HAD IT ENGRAVED... ON THE BOTTOM. IT SAID    1
# THE REAL QUESTION IS                             1
# TIME REMAINING BEFORE TERMINAL MALFUNCTION       1
# Name: speaker, dtype: int64

# %% [markdown]
# ---
# ## Post-post- cleaning

# %%
cols = ['season_num', 'episode_num', 'episode_name', 'subtitle_index', 'text', 'speaker', 'offscreen', 'start', 'end']
df_subs2 = pd.read_csv('../data/subtitle_data.csv', usecols=cols)

# %%
df_subs2
# Out:
#        subtitle_index            start              end  season_num  \
# 0                   1  00:01:52.076000  00:01:53.876000           1
# 1                   2  00:02:02.117000  00:02:03.787000           1
# 2                   3  00:02:03.887000  00:02:05.417000           1
# 3                   4  00:02:05.527000  00:02:08.088000           1
# 4                   5  00:02:08.198000  00:02:09.898000           1
# ...               ...              ...              ...         ...
# 13233             833  01:30:53.210000  01:30:54.908000           2
# 13234             834  01:30:58.833000  01:31:00.705000           2
# 13235             835  01:31:01.923000  01:31:05.251000           2
# 13236             836  01:31:08.538000  01:31:09.954000           2
# 13237             837  01:31:12.296000  01:31:13.713000           2
#
#        episode_num   episode_name  \
# 0                1   The Original
# 1                1   The Original
# 2                1   The Original
# 3                1   The Original
# 4                1   The Original
# ...            ...            ...
# 13233           10  The Passenger
# 13234           10  The Passenger
# 13235           10  The Passenger
# 13236           10  The Passenger
# 13237           10  The Passenger
#
#                                                     text  offscreen speaker
# 0                                 Bring her back online.       True     NaN
# 1                                       Can you hear me?       True     NaN
# 2                                                   Yes.       True     NaN
# 3               I'm sorry. I'm not feeling quite myself.       True     NaN
# 4                               You can lose the accent.       True     NaN
# ...                                                  ...        ...     ...
# 13233                            Longer than we thought.      False     NaN
# 13234                    I have a few questions for you.      False     NaN
# 13235  The last step's a baseline interview to allow ...      False     NaN
# 13236                                       Verify what?      False     NaN
# 13237                                          Fidelity.      False     NaN
#
# [13238 rows x 9 columns]

# %%
df_subs2.loc[df_subs2.text == ' ']
# Out:
# Empty DataFrame
# Columns: [subtitle_index, start, end, season_num, episode_num, episode_name, text, offscreen, speaker]
# Index: []
